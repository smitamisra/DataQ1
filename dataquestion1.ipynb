# %%
import pandas as pd 
import matplotlib as mpl 
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
net_migrations = pd.read_csv('data/net_migrations.csv')

# %%
net_migrations.head()
# Out:
#   Country or Area  Year    Value  Value Footnotes
# 0     Afghanistan  2012   473007              NaN
# 1     Afghanistan  2007  -677497              NaN
# 2     Afghanistan  2002   804120              NaN
# 3     Afghanistan  1997  -379474              NaN
# 4     Afghanistan  1992  2227474              NaN

# %%
internet_users = pd.read_csv('./data/internet_users.csv', nrows=4496)

# %%
internet_users.head()
# Out:
#   Country or Area    Year     Value  Value Footnotes  Unnamed: 4  Unnamed: 5
# 0     Afghanistan  2014.0  6.390000              NaN         NaN         NaN
# 1     Afghanistan  2013.0  5.900000              NaN         NaN         NaN
# 2     Afghanistan  2012.0  5.454545              NaN         NaN         NaN
# 3     Afghanistan  2011.0  5.000000              NaN         NaN         NaN
# 4     Afghanistan  2010.0  4.000000              NaN         NaN         NaN

# %%
internet_users
# Out:
#      Country or Area    Year      Value  Value Footnotes  Unnamed: 4  \
# 0        Afghanistan  2014.0   6.390000              NaN         NaN
# 1        Afghanistan  2013.0   5.900000              NaN         NaN
# 2        Afghanistan  2012.0   5.454545              NaN         NaN
# 3        Afghanistan  2011.0   5.000000              NaN         NaN
# 4        Afghanistan  2010.0   4.000000              NaN         NaN
# 5        Afghanistan  2009.0   3.550000              NaN         NaN
# 6        Afghanistan  2008.0   1.840000              NaN         NaN
# 7        Afghanistan  2007.0   1.900000              NaN         NaN
# 8        Afghanistan  2006.0   2.107124              NaN         NaN
# 9        Afghanistan  2005.0   1.224148              NaN         NaN
# 10       Afghanistan  2004.0   0.105809              NaN         NaN
# 11       Afghanistan  2003.0   0.087891              NaN         NaN
# 12       Afghanistan  2002.0   0.004561              NaN         NaN
# ...

# %%
internet_users.head(6)
# Out:
#   Country or Area    Year     Value  Value Footnotes  Unnamed: 4  Unnamed: 5
# 0     Afghanistan  2014.0  6.390000              NaN         NaN         NaN
# 1     Afghanistan  2013.0  5.900000              NaN         NaN         NaN
# 2     Afghanistan  2012.0  5.454545              NaN         NaN         NaN
# 3     Afghanistan  2011.0  5.000000              NaN         NaN         NaN
# 4     Afghanistan  2010.0  4.000000              NaN         NaN         NaN
# 5     Afghanistan  2009.0  3.550000              NaN         NaN         NaN

# %%
net_migrations.head(6)
# Out:
#   Country or Area  Year    Value  Value Footnotes
# 0     Afghanistan  2012   473007              NaN
# 1     Afghanistan  2007  -677497              NaN
# 2     Afghanistan  2002   804120              NaN
# 3     Afghanistan  1997  -379474              NaN
# 4     Afghanistan  1992  2227474              NaN
# 5     Afghanistan  1987 -1484185              NaN

# %%
internet_users.drop('Value Footnotes', axis=1, inplace=True)

# %%
net_migrations.drop('Value Footnotes', axis=1, inplace=True)

# %%
net_migrations.head()
# Out:
#   Country or Area  Year    Value
# 0     Afghanistan  2012   473007
# 1     Afghanistan  2007  -677497
# 2     Afghanistan  2002   804120
# 3     Afghanistan  1997  -379474
# 4     Afghanistan  1992  2227474

# %%
internet_users.head()
# Out:
#   Country or Area    Year     Value  Unnamed: 4  Unnamed: 5
# 0     Afghanistan  2014.0  6.390000         NaN         NaN
# 1     Afghanistan  2013.0  5.900000         NaN         NaN
# 2     Afghanistan  2012.0  5.454545         NaN         NaN
# 3     Afghanistan  2011.0  5.000000         NaN         NaN
# 4     Afghanistan  2010.0  4.000000         NaN         NaN

# %%
internet_users.rename(
  columns={
    'Country or Area' : 'Country',
    'Year' : 'Year',
    'Value' : 'Internet_Users_Pct'
  },
  inplace=True
)

# %%
internet_users.head()
# Out:
#        Country    Year  Internet_Users_Pct  Unnamed: 4  Unnamed: 5
# 0  Afghanistan  2014.0            6.390000         NaN         NaN
# 1  Afghanistan  2013.0            5.900000         NaN         NaN
# 2  Afghanistan  2012.0            5.454545         NaN         NaN
# 3  Afghanistan  2011.0            5.000000         NaN         NaN
# 4  Afghanistan  2010.0            4.000000         NaN         NaN

# %%
net_migrations.head()
# Out:
#   Country or Area  Year    Value
# 0     Afghanistan  2012   473007
# 1     Afghanistan  2007  -677497
# 2     Afghanistan  2002   804120
# 3     Afghanistan  1997  -379474
# 4     Afghanistan  1992  2227474

# %%
net_migrations.rename(
  columns={
    'Country or Area' : 'Country',
    'Year' : 'Year',
    'Value' : 'Net_Migration'
  },
  inplace=True
)

# %%
net_migrations.head()
# Out:
#        Country  Year  Net_Migration
# 0  Afghanistan  2012         473007
# 1  Afghanistan  2007        -677497
# 2  Afghanistan  2002         804120
# 3  Afghanistan  1997        -379474
# 4  Afghanistan  1992        2227474

# %%
internet_users.drop('Unnamed: 4', axis=1, inplace=True)

# %%
internet_users.drop('Unnamed: 5', axis=1, inplace=True)

# %%
internet_users.head()
# Out:
#        Country    Year  Internet_Users_Pct
# 0  Afghanistan  2014.0            6.390000
# 1  Afghanistan  2013.0            5.900000
# 2  Afghanistan  2012.0            5.454545
# 3  Afghanistan  2011.0            5.000000
# 4  Afghanistan  2010.0            4.000000

# %%
merged_data=pd.merge(internet_users, net_migrations, on=['Year', 'Country'])

# %%
merged_data.head()
# Out:
#        Country  Year  Internet_Users_Pct  Net_Migration
# 0  Afghanistan  2012            5.454545         473007
# 1  Afghanistan  2007            1.900000        -677497
# 2  Afghanistan  2002            0.004561         804120
# 3      Albania  2012           54.655959         -91750
# 4      Albania  2007           15.036115        -252926
